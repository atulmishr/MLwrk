# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ##LOAD & GETTING TO KNOW ABOUT YOUR DATASET

# %%
#Load the Dataset
data = pd.read_csv('C:\Users\ATUL\Desktop\CANCER\data.csv')
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
data.shape
# Out:
# (569, 33)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=569, step=1)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.columns
# Out:
# Index([u'id', u'diagnosis', u'radius_mean', u'texture_mean', u'perimeter_mean',
#        u'area_mean', u'smoothness_mean', u'compactness_mean',
#        u'concavity_mean', u'concave points_mean', u'symmetry_mean',
#        u'fractal_dimension_mean', u'radius_se', u'texture_se', u'perimeter_se',
#        u'area_se', u'smoothness_se', u'compactness_se', u'concavity_se',
#        u'concave points_se', u'symmetry_se', u'fractal_dimension_se',
#        u'radius_worst', u'texture_worst', u'perimeter_worst', u'area_worst',
#        u'smoothness_worst', u'compactness_worst', u'concavity_worst',
#        u'concave points_worst', u'symmetry_worst', u'fractal_dimension_worst',
#        u'Unnamed: 32'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %% [markdown]
# ## NOW, WE ARE CHECKING THE MISSING VALUES IN DATASET

# %%
data.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [markdown]
# M. ##NOW,DROP THE IRRELEVANT COLUMNS FROM THE DATASET

# %%
x_can=data.drop(columns= ['Unnamed: 32','id'])
x_can.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# ...

# %% [markdown]
# ##CONVERSION OF ATTRIBUTES

# %%
 x_can['diagonsis'] = np.where(x_can['diagnosis'] == 'M',1,0)

# %%
x_can.tail()
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean    ...      texture_worst  perimeter_worst  area_worst  \
# ...

# %% [markdown]
# ##NOW COMING TO THE PART OF UNIVARIATE ANALYSIS

# %%
x_can.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %% [markdown]
# ## Now check a every attribute with graphical visualization wheather it is categorical and quantitive..

# %%
x_can['radius_mean'].value_counts()
# Out:
# 12.340    4
# 12.770    3
# 15.460    3
# 12.890    3
# 13.050    3
# 11.710    3
# 13.850    3
# 11.890    3
# 10.260    3
# 12.180    3
# 11.060    3
# 12.460    3
# 13.170    3
# 13.000    3
# 11.600    3
# 12.050    2
# 19.400    2
# 14.950    2
# 12.360    2
# 12.540    2
# 13.770    2
# 14.870    2
# 13.870    2
# 13.280    2
# 15.780    2
# 11.930    2
# 14.580    2
# 13.400    2
# 10.480    2
# 18.220    2
#          ..
# 15.060    1
# 21.160    1
# 17.190    1
# 20.480    1
# 12.220    1
# 16.030    1
# 18.820    1
# 9.405     1
# 19.180    1
# 10.080    1
# 20.090    1
# 17.350    1
# 19.190    1
# 18.490    1
# 8.878     1
# 13.690    1
# 9.667     1
# 13.030    1
# 14.020    1
# 13.240    1
# 11.630    1
# 12.780    1
# 16.070    1
# 15.280    1
# 20.640    1
# 12.310    1
# 18.810    1
# 13.300    1
# 23.090    1
# 18.250    1
# Name: radius_mean, Length: 456, dtype: int64

# %%
plt.figure(figsize=(30,15))
plt.subplot(221)
sns.kdeplot(x_can['radius_mean'],shade=True,color='Red')
plt.subplot(222)
sns.distplot(x_can['radius_mean'],kde=True,color='blue')
plt.subplot(223)
sns.boxplot(x_can['radius_mean'],color='Yellow')
plt.subplot(224)
sns.violinplot(x_can['radius_mean'],color='cyan')

# %%
x_can['radius_worst'].value_counts()
# Out:
# 12.360    5
# 13.500    4
# 13.340    4
# 13.740    3
# 12.980    3
# 16.760    3
# 15.110    3
# 16.460    3
# 15.050    3
# 11.920    3
# 14.800    3
# 16.410    3
# 13.060    3
# 12.400    3
# 16.110    3
# 13.350    3
# 15.530    3
# 13.450    3
# 15.140    3
# 13.750    3
# 19.850    3
# 12.840    3
# 14.910    3
# 11.020    2
# 12.020    2
# 10.930    2
# 10.850    2
# 13.360    2
# 14.980    2
# 13.320    2
#          ..
# 10.760    1
# 19.180    1
# 14.850    1
# 23.240    1
# 16.300    1
# 25.280    1
# 15.890    1
# 13.780    1
# 18.490    1
# 12.260    1
# 10.510    1
# 11.990    1
# 19.770    1
# 25.680    1
# 20.190    1
# 11.620    1
# 9.628     1
# 12.770    1
# 11.240    1
# 13.130    1
# 24.560    1
# 11.520    1
# 13.160    1
# 12.780    1
# 18.330    1
# 17.870    1
# 13.280    1
# 15.800    1
# 10.170    1
# 12.820    1
# Name: radius_worst, Length: 457, dtype: int64

# %%
plt.figure(figsize=(30,15))
plt.subplot(221)
sns.kdeplot(x_can['radius_worst'],shade=True,color='k')
plt.subplot(222)
sns.distplot(x_can['radius_worst'],kde=True,color='red')
plt.subplot(223)
sns.boxplot(x_can['radius_worst'],color='purple')
plt.subplot(224)
sns.violinplot(x_can['radius_worst'],color='orange')

# %%
x_can['radius_se'].value_counts()
# Out:
# 0.2860    3
# 0.2204    3
# 0.2315    2
# 0.3380    2
# 0.3276    2
# 0.2562    2
# 0.1630    2
# 0.2577    2
# 0.1840    2
# 0.2976    2
# 0.1924    2
# 0.2621    2
# 0.3534    2
# 0.5079    2
# 0.2351    2
# 0.3060    2
# 0.2239    2
# 0.5959    2
# 0.2067    2
# 0.1532    2
# 0.2684    2
# 0.2244    2
# 0.1601    2
# 0.2957    2
# 0.4101    2
# 0.2430    2
# 0.4030    2
# 0.2959    1
# 0.4866    1
# 0.2711    1
#          ..
# 0.5907    1
# 0.4384    1
# 0.3908    1
# 0.4653    1
# 1.0720    1
# 0.3093    1
# 0.4222    1
# 0.3191    1
# 0.4309    1
# 0.1302    1
# 0.5115    1
# 0.9622    1
# 0.2497    1
# 0.3550    1
# 0.2963    1
# 0.1818    1
# 0.2102    1
# 0.1642    1
# 0.3249    1
# 0.7275    1
# 0.3971    1
# 0.2182    1
# 0.3028    1
# 0.2241    1
# 0.6642    1
# 0.3428    1
# 0.5366    1
# 0.4250    1
# 0.7661    1
# 0.2500    1
# Name: radius_se, Length: 540, dtype: int64

# %%
plt.figure(figsize=(30,15))
plt.subplot(221)
sns.kdeplot(x_can['radius_se'],shade=True,color='magenta')
plt.subplot(222)
sns.distplot(x_can['radius_se'],kde=True,color='Red')
plt.subplot(223)
sns.boxplot(x_can['radius_se'],color='cyan')
plt.subplot(224)
sns.violinplot(x_can['radius_se'],color='orange')

# %%
x_can['texture_mean'].value_counts()
# Out:
# 14.93    3
# 15.70    3
# 18.90    3
# 16.84    3
# 17.46    3
# 18.22    3
# 20.52    3
# 16.85    3
# 19.83    3
# 18.89    2
# 13.98    2
# 20.22    2
# 18.18    2
# 18.61    2
# 21.25    2
# 27.15    2
# 21.84    2
# 14.96    2
# 16.58    2
# 20.76    2
# 21.53    2
# 15.51    2
# 21.46    2
# 21.59    2
# 13.90    2
# 17.12    2
# 16.62    2
# 21.54    2
# 19.04    2
# 20.74    2
#         ..
# 24.91    1
# 14.23    1
# 15.62    1
# 20.97    1
# 12.27    1
# 24.68    1
# 19.31    1
# 16.54    1
# 23.23    1
# 17.26    1
# 18.06    1
# 19.29    1
# 21.57    1
# 25.56    1
# 14.36    1
# 13.29    1
# 22.14    1
# 18.83    1
# 27.06    1
# 19.35    1
# 12.17    1
# 14.78    1
# 15.39    1
# 11.89    1
# 16.03    1
# 20.53    1
# 17.66    1
# 24.80    1
# 20.56    1
# 10.94    1
# Name: texture_mean, Length: 479, dtype: int64

# %%
plt.figure(figsize=(30,15))
plt.subplot(221)
sns.kdeplot(x_can['texture_mean'],shade=True,color='red')
plt.subplot(222)
sns.distplot(x_can['texture_mean'],kde=True,color='violet')
plt.subplot(223)
sns.boxplot(x_can['texture_mean'],color='cyan')
plt.subplot(224)
sns.violinplot(x_can['texture_mean'],color='orange')

# %%
x_can['texture_worst'].value_counts()
# Out:
# 27.26    3
# 17.70    3
# 28.18    2
# 25.09    2
# 19.35    2
# 34.01    2
# 25.59    2
# 26.44    2
# 25.80    2
# 20.83    2
# 23.07    2
# 23.03    2
# 17.04    2
# 28.46    2
# 26.93    2
# 33.17    2
# 15.77    2
# 29.41    2
# 28.07    2
# 25.58    2
# 29.02    2
# 30.36    2
# 27.78    2
# 22.15    2
# 22.02    2
# 28.14    2
# 23.58    2
# 16.93    2
# 32.82    2
# 21.40    2
#         ..
# 21.38    1
# 24.56    1
# 17.58    1
# 34.24    1
# 24.04    1
# 31.98    1
# 30.76    1
# 12.02    1
# 25.07    1
# 39.42    1
# 24.82    1
# 22.06    1
# 25.72    1
# 24.39    1
# 19.62    1
# 30.39    1
# 20.72    1
# 26.06    1
# 16.85    1
# 34.12    1
# 25.53    1
# 38.81    1
# 32.06    1
# 23.05    1
# 31.03    1
# 36.32    1
# 25.20    1
# 15.40    1
# 36.92    1
# 26.50    1
# Name: texture_worst, Length: 511, dtype: int64

# %%
plt.figure(figsize=(30,15))
plt.subplot(221)
sns.kdeplot(x_can['texture_worst'],shade=True,color='k')
plt.subplot(222)
sns.distplot(x_can['texture_worst'],kde=True,color='red')
plt.subplot(223)
sns.boxplot(x_can['texture_worst'],color='blue')
plt.subplot(224)
sns.violinplot(x_can['texture_worst'],color='orange')

# %%
x_can['texture_se'].value_counts()
# Out:
# 1.3500    3
# 1.2680    3
# 0.8561    3
# 1.1500    3
# 1.4280    2
# 0.9429    2
# 1.1690    2
# 1.3900    2
# 1.1660    2
# 1.1990    2
# 1.0330    2
# 1.0230    2
# 1.3050    2
# 1.1520    2
# 1.5630    2
# 1.3630    2
# 1.0270    2
# 0.7339    2
# 1.0950    2
# 0.8225    2
# 1.3420    2
# 1.2160    2
# 1.0460    2
# 1.0590    2
# 1.0450    2
# 1.2170    2
# 1.7430    2
# 1.2140    2
# 1.0010    2
# 0.9209    2
#          ..
# 1.5550    1
# 0.8836    1
# 1.3520    1
# 0.3621    1
# 0.9988    1
# 1.8490    1
# 0.6221    1
# 0.6583    1
# 2.7770    1
# 1.0720    1
# 1.1900    1
# 1.1780    1
# 1.3980    1
# 1.2560    1
# 2.4540    1
# 0.9017    1
# 2.1290    1
# 0.7747    1
# 1.5450    1
# 1.1300    1
# 0.5040    1
# 2.0150    1
# 2.9100    1
# 0.3871    1
# 0.6633    1
# 0.8339    1
# 0.8652    1
# 1.2000    1
# 1.9250    1
# 1.3750    1
# Name: texture_se, Length: 519, dtype: int64

# %%
plt.figure(figsize=(30,15))
plt.subplot(221)
sns.kdeplot(x_can['texture_se'],shade=True,color='k')
plt.subplot(222)
sns.distplot(x_can['texture_se'],kde=True,color='red')
plt.subplot(223)
sns.boxplot(x_can['texture_se'],color='yellow')
plt.subplot(224)
sns.violinplot(x_can['texture_se'],color='green')

# %%
plt.figure(figsize=(30,15))
plt.subplot(221)
sns.kdeplot(x_can['area_mean'],shade=True,color='magenta')
plt.subplot(222)
sns.distplot(x_can['area_mean'],kde=True,color='violet')
plt.subplot(223)
sns.boxplot(x_can['area_mean'],color='black')
plt.subplot(224)
sns.violinplot(x_can['area_mean'],color='orange')

# %%
plt.figure(figsize=(30,15))
plt.subplot(221)
sns.kdeplot(x_can['concavity_mean'],shade=True,color='gray')
plt.subplot(222)
sns.distplot(x_can['concavity_mean'],kde=True,color='blue')
plt.subplot(223)
sns.boxplot(x_can['concavity_mean'],color='Yellow')
plt.subplot(224)
sns.violinplot(x_can['concavity_mean'],color='orange')

# %%
plt.figure(figsize=(30,15))
plt.subplot(221)
sns.kdeplot(x_can['symmetry_mean'],shade=True,color='gray')
plt.subplot(222)
sns.distplot(x_can['symmetry_mean'],kde=True,color='purple')
plt.subplot(223)
sns.boxplot(x_can['symmetry_mean'],color='k')
plt.subplot(224)
sns.violinplot(x_can['symmetry_mean'],color='orange')

# %%
plt.figure(figsize=(30,15))
plt.subplot(221)
sns.kdeplot(x_can['fractal_dimension_mean'],shade=True,color='gray')
plt.subplot(222)
sns.distplot(x_can['fractal_dimension_mean'],kde=True,color='green')
plt.subplot(223)
sns.boxplot(x_can['fractal_dimension_mean'],color='k')
plt.subplot(224)
sns.violinplot(x_can['fractal_dimension_mean'],color='red')

# %%
plt.figure(figsize=(30,15))
plt.subplot(221)
sns.kdeplot(x_can['concave points_mean'],shade=True,color='red')
plt.subplot(222)
sns.distplot(x_can['concave points_mean'],kde=True,color='red')
plt.subplot(223)
sns.boxplot(x_can['concave points_mean'],color='green')
plt.subplot(224)
sns.violinplot(x_can['concave points_mean'],color='orange')

# %%
plt.figure(figsize=(30,15))
plt.subplot(221)
sns.kdeplot(x_can['smoothness_mean'],shade=True,color='k')
plt.subplot(222)
sns.distplot(x_can['smoothness_mean'],kde=True,color='red')
plt.subplot(223)
sns.boxplot(x_can['smoothness_mean'],color='green')
plt.subplot(224)
sns.violinplot(x_can['smoothness_mean'],color='orange')

# %%
plt.figure(figsize=(30,15))
plt.subplot(221)
sns.kdeplot(x_can['symmetry_worst'],shade=True,color='k')
plt.subplot(222)
sns.distplot(x_can['symmetry_worst'],kde=True,color='red')
plt.subplot(223)
sns.boxplot(x_can['symmetry_worst'],color='b')
plt.subplot(224)
sns.violinplot(x_can['symmetry_worst'],color='green')

# %%
plt.figure(figsize=(30,15))
plt.subplot(221)
sns.kdeplot(x_can['fractal_dimension_worst'],shade=True,color='magenta')
plt.subplot(222)
sns.distplot(x_can['fractal_dimension_worst'],kde=True,color='red')
plt.subplot(223)
sns.boxplot(x_can['fractal_dimension_worst'],color='black')
plt.subplot(224)
sns.violinplot(x_can['fractal_dimension_worst'],color='green')

# %%
plt.figure(figsize=(30,15))
plt.subplot(221)
sns.kdeplot(x_can['fractal_dimension_se'],shade=True,color='red')
plt.subplot(222)
sns.distplot(x_can['fractal_dimension_se'],kde=True,color='magenta')
plt.subplot(223)
sns.boxplot(x_can['fractal_dimension_se'],color='green')
plt.subplot(224)
sns.violinplot(x_can['fractal_dimension_se'],color='k')

# %%
# Out:
# 512.2     3
# 1214.0    2
# 399.8     2
# 758.6     2
# 1075.0    2
# 372.7     2
# 684.5     2
# 716.6     2
# 1138.0    2
# 658.8     2
# 559.2     2
# 506.3     2
# 321.6     2
# 334.2     2
# 537.3     2
# 477.3     2
# 361.6     2
# 575.3     2
# 514.3     2
# 641.2     2
# 520.0     2
# 1076.0    2
# 466.1     2
# 1264.0    2
# 432.0     2
# 582.7     2
# 394.1     2
# 561.0     2
# 420.3     2
# 519.8     1
#          ..
# 248.7     1
# 507.6     1
# 781.0     1
# 1033.0    1
# 412.5     1
# 1155.0    1
# 317.5     1
# 321.4     1
# 1290.0    1
# 514.5     1
# 371.5     1
# 451.1     1
# 476.5     1
# 599.5     1
# 571.0     1
# 2010.0    1
# 933.1     1
# 464.1     1
# 420.5     1
# 566.3     1
# 466.5     1
# 246.3     1
# 680.7     1
# 516.6     1
# 412.6     1
# 704.4     1
# 904.6     1
# 646.1     1
# 300.2     1
# 1001.0    1
# Name: area_mean, Length: 539, dtype: int64
